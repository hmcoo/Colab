# %% [markdown]
# <a href="https://colab.research.google.com/github/hmcoo/Colab/blob/master/Copy_of_Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = keras.Sequential([keras.layers.Dense(units=2, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0], dtype=float)
ys = np.array([-1.0, -0.5, 0.0,0.5, 1.0, 1.5, 2.0, 2.5], dtype=float)
model.fit(xs, ys, epochs=600)
print(model.predict([7.0]))
# Out:
# Epoch 1/600
# 8/8 [==============================] - 0s 29ms/sample - loss: 10.9957
# Epoch 2/600
# 8/8 [==============================] - 0s 393us/sample - loss: 9.5710
# Epoch 3/600
# 8/8 [==============================] - 0s 247us/sample - loss: 8.3435
# Epoch 4/600
# 8/8 [==============================] - 0s 251us/sample - loss: 7.2859
# Epoch 5/600
# 8/8 [==============================] - 0s 211us/sample - loss: 6.3746
# Epoch 6/600
# 8/8 [==============================] - 0s 264us/sample - loss: 5.5893
# Epoch 7/600
# 8/8 [==============================] - 0s 371us/sample - loss: 4.9125
# Epoch 8/600
# 8/8 [==============================] - 0s 238us/sample - loss: 4.3292
# Epoch 9/600
# 8/8 [==============================] - 0s 257us/sample - loss: 3.8265
# Epoch 10/600
# 8/8 [==============================] - 0s 211us/sample - loss: 3.3931
# Epoch 11/600
# 8/8 [==============================] - 0s 346us/sample - loss: 3.0195
# Epoch 12/600
# ...
